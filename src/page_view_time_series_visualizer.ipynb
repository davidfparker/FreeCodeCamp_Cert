# %%
# import libraries
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import pandas as pd
import seaborn as sns
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
df=pd.read_csv('../data/fcc-forum-pageviews.csv',parse_dates=['date'],index_col= ['date'])

# %%
df.shape
# Out:
# (1304, 1)

# %%
df = df[(df['value'] >= df['value'].quantile(0.025)) & (df['value'] <= df['value'].quantile(0.975))]

# %%
df.shape
# Out:
# (1238, 1)

# %%
df
# Out:
#              value
# date
# 2016-05-19   19736
# 2016-05-26   18060
# 2016-05-27   19997
# 2016-05-28   19044
# 2016-05-29   20325
# ...            ...
# 2019-11-24  138875
# 2019-11-29  171584
# 2019-11-30  141161
# 2019-12-01  142918
# 2019-12-03  158549
#
# [1238 rows x 1 columns]

# %%
fig, ax = plt.subplots(figsize=(16, 9))
ax.plot(df.index.values,
       df['value'],
       color='red')
ax.set(xlabel="Date",
       ylabel="Page Views",
       title="Daily freeCodeCamp Forum Page Views 5/2016-12/2019")
date_form = DateFormatter("%Y-%m")
ax.xaxis.set_major_formatter(date_form)
ax.xaxis.set_major_locator(mdates.MonthLocator([1,7]))

# %%
date_form = DateFormatter("%Y-%m")
plt.rcParams["figure.figsize"] = [16,9]
plt.plot(df.index, df['value'], color='red')
plt.title('Daily freeCodeCamp Forum Page Views 5/2016-12/2019')
plt.xlabel('Date')
plt.ylabel('Page Views')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-140-ba0c791b98f2> in <module>
#       6 plt.ylabel('Page Views')
#       7 date_form = DateFormatter("%Y-%m")
# ----> 8 plt.xaxis.set_major_formatter(date_form)
#       9 plt.xaxis.set_major_locator(mdates.WeekdayLocator(interval=1))
#      10 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xaxis'

# %%
plot('date', 'value', data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-441a6544dd1d> in <module>
# ----> 1 plot('date', 'value', data=df)
#
# NameError: name 'plot' is not defined

# %%
def draw_line_plot():
    # Draw line plot



    # Save image and return fig (don't change this part)
    fig.savefig('line_plot.png')
    return fig

# %%
def draw_bar_plot():
    # Copy and modify data for monthly bar plot
    df_bar = None

    # Draw bar plot





    # Save image and return fig (don't change this part)
    fig.savefig('bar_plot.png')
    return fig

# %%
def draw_box_plot():
    # Prepare data for box plots (this part is done!)
    df_box = df.copy()
    df_box.reset_index(inplace=True)
    df_box['year'] = [d.year for d in df_box.date]
    df_box['month'] = [d.strftime('%b') for d in df_box.date]

    # Draw box plots (using Seaborn)





    # Save image and return fig (don't change this part)
    fig.savefig('box_plot.png')
    return fig
